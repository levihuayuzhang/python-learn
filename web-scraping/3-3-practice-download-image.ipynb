# %%
import requests
from bs4 import BeautifulSoup

# URL = "http://www.ngchina.com.cn/animals/"
URL = "https://www.natgeomedia.com/environment/"

# %%
html = requests.get(URL).text
soup = BeautifulSoup(html, "lxml")
img_div = soup.find_all("div", {"class": "art-btn-la-img"})
print(html)
print(img_div)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# 	<meta http-equiv="Content-Style-Type" content="text/css">
# 	<meta http-equiv="Content-Script-Type" content="text/javascript">
# 	<meta name="viewport" content="width=device-width,initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no"/>
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#
#
#
#
# 	<link rel="icon" type="image/png" href="/img/app_icon.png" />
# 	<link rel="apple-touch-icon" href="/img/touch-icon-iphone.png" />
# 	<link rel="apple-touch-icon" sizes="76x76" href="/img/touch-icon-ipad.png" />
# 	<link rel="apple-touch-icon" sizes="120x120" href="/img/touch-icon-iphone-retina.png" />
# 	<link rel="apple-touch-icon" sizes="152x152" href="/img/touch-icon-ipad-retina.png" />
#
#
# 	<title>ç°å¢èä¿è² - åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬</title>
#
#
#
# 	<meta property="fb:app_id" content="708677648070117"/>
# 	<meta property="og:type" content="website">
# 	<meta property="og:url" content="https://www.natgeomedia.com/environment/index.html" />
# 	<meta property="og:title" content="ç°å¢èä¿è² - åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬"/>
# 	<meta property="og:description" content="åå®¶å°çéèªï½åç¾ææ°çèªç¶ãç§å­¸ãçæèæåå°é¡å ±å°ãæ¢ç´¢åç©ä¿è­·ãç°å¢è®é·ãèå¤ç¼ç¾ç­è±å¯å§å®¹ï¼ä¸¦ééç²¾ç¾çæå½±åæ·±åº¦åæï¼å¸¶æ¨æ·±å¥äºè§£ä¸çåå°çæäºèç¾è±¡ã" />
# 	<meta property="og:image" content="https://www.natgeomedia.com/img/1200x630.jpg" />
# 	<!--
# 	<meta property="fb:pages" content="197396410423992">
# 	<meta property="og:site_name" content="åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬" />
# 	<meta property="og:image:alt" content="ç°å¢èä¿è² - åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬" />
# 	<meta property="og:image:width" content="1200">
# 	<meta property="og:image:height" content="630">
# 	-->
#
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:title" content="ç°å¢èä¿è² - åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬" />
# 	<meta name="twitter:description" content="åå®¶å°çéèªï½åç¾ææ°çèªç¶ãç§å­¸ãçæèæåå°é¡å ±å°ãæ¢ç´¢åç©ä¿è­·ãç°å¢è®é·ãèå¤ç¼ç¾ç­è±å¯å§å®¹ï¼ä¸¦ééç²¾ç¾çæå½±åæ·±åº¦åæï¼å¸¶æ¨æ·±å¥äºè§£ä¸çåå°çæäºèç¾è±¡ã" />
# 	<meta name="twitter:image" content="https://www.natgeomedia.com/img/1200x630.jpg" />
#
# 	<meta name="Title" content="ç°å¢èä¿è² - åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬" />
# 	<meta name="keywords" content="ç°å¢èä¿è²,Environment,åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬,Nat Geo" />
# 	<meta name="news_keywords" content="ç°å¢èä¿è²,Environment,åå®¶å°çéèªå®æ¹ç¶²ç«ï½æ¢ç´¢èªç¶ãç§å­¸èæåçæä½³æ¬,Nat Geo" />
# 	<meta name="description" content="åå®¶å°çéèªï½åç¾ææ°çèªç¶ãç§å­¸ãçæèæåå°é¡å ±å°ãæ¢ç´¢åç©ä¿è­·ãç°å¢è®é·ãèå¤ç¼ç¾ç­è±å¯å§å®¹ï¼ä¸¦ééç²¾ç¾çæå½±åæ·±åº¦åæï¼å¸¶æ¨æ·±å¥äºè§£ä¸çåå°çæäºèç¾è±¡ã" />
# 	<link rel="image_src" href="https://www.natgeomedia.com/img/1200x630.jpg" />
#
# 	<meta name="google-site-verification" content="HFqEkJQ6tm-aL-1NoY7U7z26fCwRV5sGLrLNFSQb-Yo" />
#
#
#
# 	<!-- Google Tag Manager -->
# 	<!-- <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-PZNPVHG');</script> -->
# 	<!-- End Google Tag Manager -->
#
# 	<!-- Google Analytics -->
# 	<!--<script>
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-48305649-1', 'auto');
# 		ga('send', 'pageview');
#
# 		setTimeout("ga('send', 'event', '1_seconds', 'read')",1000);
# 	</script>-->
#
# 	<!-- Google tag (gtag.js) -->
# 	<script async src="https://www.googletagmanager.com/gtag/js?id=G-F0ZR674BM5"></script>
# 	<script>
# 		window.dataLayer = window.dataLayer || [];
# 		function boulder_gtag(){dataLayer.push(arguments);}
# 		boulder_gtag('js', new Date());
# 		boulder_gtag('config', 'G-F0ZR674BM5');
# 		boulder_gtag('event', 'pageview', {
# 			'event_category': 'page_load',
# 			'event_label': 'pageview'
# 		});
# 		setTimeout(function(){
# 			boulder_gtag('event', '1_seconds', {
# 				'event_category': 'page_load',
# 				'event_label': 'read'
# 			});
# 		},1000)
# 	</script>
#
# 	<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9562996560895758" crossorigin="anonymous"></script>
#
#
#
#
#
#
# 	<link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css" rel="stylesheet">
# 	<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
#
# 	<link href="https://fonts.googleapis.com/css?family=Montserrat:100,100i,200,200i,300,300i,400,400i,500,500i,600,600i,700,700i,800,800i,900,900i" rel="stylesheet">
#
# 	<link href="https://fonts.googleapis.com/css?family=Roboto:100,100i,300,300i,400,400i,500,500i,700,700i,900,900i" rel="stylesheet">
#
# 	<style>
# 		@import url(https://fonts.googleapis.com/earlyaccess/notosanstc.css);
# 		/*@import url(//fonts.googleapis.com/earlyaccess/cwtexming.css);*/
# 	</style>
#
# 	<link rel="stylesheet" type="text/css" href="/css/reset.css">
# 	<link rel="stylesheet" type="text/css" href="/css/main.css?v=20251210">
# 	<link rel="stylesheet" type="text/css" href="/css/layout.css?v=20251210">
#
# 	<script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# 	<script defer src="https://use.fontawesome.com/releases/v5.0.6/js/all.js"></script>
# </head>
#
# <body>
#
#
# <!--     <div id="fb-root"></div>
#     <script>(function(d, s, id) {
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = 'https://connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.11&appId=708677648070117';
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));</script> -->
#     <nav>
# 	<div class="nav-wrapper">
#
# 		<!-- logo -->
# 		<div class="ngm-logo">
# 			<a href="/" aria-label="åå®¶å°ç">
# 				<img class="logo-b lazy" data-src="https://img.natgeomedia.com/img/ngm-logo-b.svg" alt="">
# 				<img class="logo-w hide lazy" data-src="https://img.natgeomedia.com/img/ngm-logo-w.svg" alt="">
# 			</a>
# 		</div>
#
# 		<!-- desktop nav -->
# 		<div class="desktop-mega-menu">
# 			<div class="mega-menu-wrapper">
# 				<div class="menu-item">
# 					<a href="/science/">ç§å­¸èæ°ç¥</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a href="/environment/">ç°å¢èä¿è²</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a href="/history/">æ­·å²èæå</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a href="/explore/">æ¢ç´¢èåéª</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a href="/travel/">æé</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a href="/e-mag/">é»å­éèª</a>
# 				</div>
#
# 				<div class="menu-item">
# 					<a class="more-submenu">
# 						æ´å¤ <i class="fas fa-chevron-down"></i>
# 					</a>
# 				</div>
#
# 			</div>
#
# 			<!-- navgation-menu -->
# 			<div class="nav-menu">
# 				<div class="menu-container">
#
# 					<div class="menu-content">
# 						<ul>
# 							<li>æç« </li>
# 							<li>
# 								<a href="/science/">ç§å­¸èæ°ç¥</a>
# 							</li>
#
# 							<li>
# 								<a href="/environment/">ç°å¢èä¿è²</a>
# 							</li>
#
# 							<li>
# 								<a href="/history/">æ­·å²èæå</a>
# 							</li>
#
# 							<li>
# 								<a href="/explore/">æ¢ç´¢èåéª</a>
# 							</li>
#
# 							<li>
# 								<a href="/travel/">æé</a>
# 							</li>
# 							<li>
# 								<a href="/e-mag/">é»å­éèª</a>
# 							</li>
# 						</ul>
#
# 						<ul>
# 							<li>åæ¸</li>
# 							<li>
# 								<a href="https://lihi.cc/qL7OO" target="_blank">åå</a>
# 							</li>
# 							<li>
# 								<a href="/book-news/">ææ°æ¸è¨</a>
# 							</li>
# 							<li>
# 								<a href="https://lihi.cc/qWkI3" target="_blank">ç¹å</a>
# 							</li>
# 						</ul>
# 					</div>
#
# 					<div class="menu-content">
# 						<ul>
# 							<li>å°å±¬</li>
# 							<li>
# 								<a href="/special_projects/">ä¸»é¡ä¼ç«</a>
# 							</li>
# 							<li>
# 								<a href="/magazine.asp">è¨é±æ¹æ¡</a>
# 							</li>
# 							<li>
# 								<a href="/member/paywall.asp">æ¸ä½å¨é±è®</a>
# 							</li>
# 							<li>
# 								<a href="/member/login.asp">æå¡ä¸­å¿</a>
# 							</li>
# 							<!-- <li>
# 								<a href="javascript:void(0)">è³¼ç©è»</a>
# 							</li> -->
# 						</ul>
#
# 						<ul class="submenu-marketing">
# 							<li>æ´»å</li>
# 							<li>
# 								<a href="/marketing/category-95.html">ä¸»é¡è·¯è·</a>
# 							</li>
# 							<li>
# 								<a href="/marketing/category-90.html">å°ç£æå½±å¤§è³½</a>
# 							</li>
# 							<li>
# 								<a href="/marketing/category-1434.html">éè³åºçè¨ç«</a>
# 							</li>
# 							<li>
# 								<a href="/marketing/">æ´å¤æ´»å</a>
# 							</li>
# 						</ul>
#
# 						<ul>
# 							<li>è¿æç¦é»</li>
# 							<li>
# 								<a href="https://www.natgeomedia.com/crowdfunding/ocean-odyssey?utm_source=web&utm_medium=system&utm_term=menu" target="_blank">
# 									<figure>
# 										<img src="/img/album/event-thumb-20260701.jpg" alt="2026 æµ·æ´å¨æ¸åºçé è³¼">
# 										<figcaption style="letter-spacing: 0;">2026 æµ·æ´å¨æ¸åºçé è³¼</figcaption>
# 									</figure>
# 								</a>
# 							</li>
# 						</ul>
# 					</div>
#
# 				</div>
# 			</div>
# 		</div>
#
# 		<!-- hamburger menu -->
# 		<div class="nav-icon">
# 			<div class="nav-icon-line nav-icon-line-1"></div>
# 			<div class="nav-icon-line nav-icon-line-2"></div>
# 			<div class="nav-icon-line nav-icon-line-3"></div>
# 		</div>
#
# 		<!-- icons -->
# 		<div class="navbar-icons">
# 			<!-- shopping -->
# 			<div class="navbar-shop">
# 				<a href="https://lihi.cc/qL7OO" aria-label="å¤§ç³åå" target="_blank">
# 					<i class="fas fa-shopping-bag"></i>
# 				</a>
# 			</div>
#
# 			<!-- search -->
# 			<div class="navbar-search">
# 				<a href="#" aria-label="æå° Search" onclick="return false;">
# 					<i class="fas fa-search"></i>
# 				</a>
# 			</div>
#
# 			<!-- user -->
# 			<div class="navbar-user">
# 				<a href="#" aria-label="User" onclick="return false;">
# 					<i class="fas fa-user"></i>
# 				</a>
# 			</div>
#
# 			<!-- cart -->
# 			<div class="navbar-cart">
# 				<a href="/magazine.html">
# 					<!-- black -->
# 					<div class="navbar-cart-icon navbar-cart-b">
# 						<img src="https://img.natgeomedia.com/img/icon-order-b.svg" alt="">
# 					</div>
#
# 					<!-- white -->
# 					<div class="navbar-cart-icon hide">
# 						<img src="https://img.natgeomedia.com/img/icon-order-w.svg" alt="">
# 					</div>
# 				</a>
# 			</div>
#
# 		</div>
#
# 		<!-- user function -->
# 		<div class="user-function">
#
# 			<!-- æªç»å¥ççæ -->
# 			<div class="user-f-container user-login" style="display:block;">
# 				<p>è«åç»å¥</p>
# 				<div class="cube-btn user-btn">
# 					ç»å¥
# 					<a href="/member/login.asp"></a>
# 				</div>
# 			</div>
#
# 		</div>
# 	</div>
# </nav>
#
#
# <script src="https://img.natgeomedia.com/js/user-function.js"></script>
#
#
# 	<!-- search -->
# 	<div class="search-load">
# 		<section class="search-content">
#
# 			<div class="search-content-range">
#
# 				<div class="search-check">
# 					<input type="radio" class="Search-Type" name="sType" value="1" checked><span>å¨ç«æå°</span>
# 					<input type="radio" class="Search-Type" name="sType" value="2"><span>é»å­éèªæå°</span>
# 				</div>
#
# 				<form name="Search-Form" action="/search/" method="get" onsubmit="return searchChk()">
# 				<input type="hidden" id="cx-val" name="cx" value="07e9df721e2064180">
# 				<input type="text" id="Search-Str" name="q" class="search-input" placeholder="è«è¼¸å¥æå°ééµå­">
# 				<button type="submit" aria-label="éåé¸å®" class="search-submit-btn">
# 					<i class="fas fa-search"></i>
# 				</button>
# 				</form>
# 			</div>
#
# 			<!-- close -->
# 			<div class="icon-close search-close">
# 				<div class="icon-close-line bg-white"></div>
# 				<div class="icon-close-line bg-white"></div>
# 			</div>
#
# 		</section>
# 	</div>
#
# 	<script type="text/javascript">
# 	function searchChk(){
# 		if($('#Search-Str').val()==''){
# 			alert('è«è¼¸å¥æå°ééµå­');
# 			return false;
# 		}
# 		return true;
# 	}
# 	$(function(){
# 		$('.Search-Type').click(function(){
# 			if(parseInt($(this).val())==1){
# 				$('#cx-val').val('07e9df721e2064180');
# 			}else{
# 				$('#cx-val').val('750e5fd82889f4d7f');
# 			}
# 		});
# 	});
# 	</script>
#
#
#
#
# 	<!-- banner -->
# 	<section class="unit-banner" style="background:url(/img/category/banner-environment.jpg) no-repeat;background-size:cover;background-position:50% 60%;">
# 		<div class="banner-title">
# 			<h3 class="banner-h3">Environment</h3>
# 			<h2 class="banner-h2">ç°å¢èä¿è²</h2>
# 		</div>
# 	</section>
#
#
# 	<!-- sub-nav -->
# 	<div id="sub-nav" class="sub-nav">
# 		<div class="sub-nav-container">
# 			<ul class="scrollmenu-horizontal">
# 				<a href="/environment/index.html">
# 					<li class="sub-nav-active">å¨é¨</li>
# 				</a>
#
# 				<a href="/environment/article/index.html">
# 					<li>æç« ç¸½å¯</li>
# 				</a>
#
# 				<a href="/environment/photo/index.html">
# 					<li>æ¯æ¥ä¸å</li>
# 				</a>
#
# 				<a href="/environment/gallery/index.html">
# 					<li>å½±åèå»</li>
# 				</a>
#
# 				<a href="/environment/video/index.html">
# 					<li>å½±é³ç²¾é¸</li>
# 				</a>
# 			</ul>
# 		</div>
# 	</div>
#
#
#
# 	<!-- article content all -->
# 	<section class="content-all">
#
# 		<div class="article-link-content">
#
# 			<!-- top article link -->
#
# 			<div class="article-link-w100">
#
# 				<!-- article btn large -->
# 				<div class="artcle-btn-large">
#
# 					<!-- large -->
#
# 					<div class="art-btn-large">
# 						<div class="art-btn-la-content">
# 							<a href="https://www.natgeomedia.com/environment/article/content-19297.html">
# 								<!-- img -->
# 								<div class="art-btn-la-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm564376_images_A1/19297/2026081044645521.jpg" alt="æ¸æçª©å¨æ²è£¡ä¹è½çå­ åèå¯æçãæ²æ¼ é¨èãé£æµäººé¡éç¼">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-la-text text-white">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Aug. 10 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/article/content-19297.html" class="text-white">
# 											æ¸æçª©å¨æ²è£¡ä¹è½çå­ åèå¯æçãæ²æ¼ é¨èãé£æµäººé¡éç¼
# 										</a>
# 									</h4>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-white">
# 										<a class="text-white" href="https://www.natgeomedia.com/environment/article/content-19297.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
# 					</div>
#
#
# 				</div>
# 				<!-- END OF article btn large -->
#
# 				<!-- article btn small -->
# 				<div class="artile-btn-small">
#
#
# 					<!-- small -->
# 					<div class="art-btn-s-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19273.html">
# 							<!-- img -->
# 							<div class="art-btn-s-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm154103_images_A1/19273/2026080338184469.jpg" alt="æ±¡æ°´èçæ¼æ´è®å¤§è¥¿æ´é®­æä¸ãå¤æ¯é¹¼ã ç§å­¸å®¶æ­ï¼æ¸¸å¾æ´å¿«æ´é ">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-s-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Aug. 03 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19273.html" class="text-black">
# 										æ±¡æ°´èçæ¼æ´è®å¤§è¥¿æ´é®­æä¸ãå¤æ¯é¹¼ã ç§å­¸å®¶æ­ï¼æ¸¸å¾æ´å¿«æ´é
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black desktop-hide mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19273.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 					<!-- small -->
# 					<div class="art-btn-s-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19272.html">
# 							<!-- img -->
# 							<div class="art-btn-s-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm154103_images_A1/19272/2026080276763825.jpg" alt="äººé¡æ´»åå¦ä½å½±é¿éäºæè®æ§çé­ï¼">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-s-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Aug. 02 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19272.html" class="text-black">
# 										äººé¡æ´»åå¦ä½å½±é¿éäºæè®æ§çé­ï¼
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black desktop-hide mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19272.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 					<!-- small -->
# 					<div class="art-btn-s-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19248.html">
# 							<!-- img -->
# 							<div class="art-btn-s-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm154103_images_A1/19248/2026073076614209.jpg" alt="å¾ãäººå·¥èãå­µåºä¾çå°é">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-s-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Jul. 30 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19248.html" class="text-black">
# 										å¾ãäººå·¥èãå­µåºä¾çå°é
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black desktop-hide mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19248.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
#
# 				</div>
# 				<!-- END OF article btn small -->
#
# 				<div class="clearfix"></div>
#
#
#
# 				<!-- article btn meddle vertical -->
# 				<div class="artcle-btn-mv">
# 					<!-- middle vertical -->
# 					<div class="art-btn-mv-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19241.html">
# 							<!-- img -->
# 							<div class="art-btn-mv-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm324216_images_A1/19241/2026072675973609.jpg" alt="æ¿æ±æ·ºæµ·é¾æµ·è±åCTçäºº å°è¨ªé¦åµæµ·æ´åç©å½±åè§£åçé¦æ¸¯å°å®¶">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-mv-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Jul. 27 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19241.html" class="text-black">
# 										æ¿æ±æ·ºæµ·é¾æµ·è±åCTçäºº å°è¨ªé¦åµæµ·æ´åç©å½±åè§£åçé¦æ¸¯å°å®¶
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19241.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 				</div>
# 				<!-- END OF article btn meddle vertical -->
#
# 				<!-- article btn meddle vertical -->
# 				<div class="artcle-btn-mv">
# 					<!-- middle vertical -->
# 					<div class="art-btn-mv-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19243.html">
# 							<!-- img -->
# 							<div class="art-btn-mv-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm324216_images_A1/19243/2026072739833981.jpg" alt="å¤ä»£ååçæå¥³æ§ï¼å¶å¯¦æ¯æ°å£«å¬ä¸»ï¼">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-mv-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Jul. 27 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19243.html" class="text-black">
# 										å¤ä»£ååçæå¥³æ§ï¼å¶å¯¦æ¯æ°å£«å¬ä¸»ï¼
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19243.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 				</div>
# 				<!-- END OF article btn meddle vertical -->
#
# 				<!-- article btn meddle vertical -->
# 				<div class="artcle-btn-mv">
# 					<!-- middle vertical -->
# 					<div class="art-btn-mv-content">
# 						<a href="https://www.natgeomedia.com/environment/article/content-19234.html">
# 							<!-- img -->
# 							<div class="art-btn-mv-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm324216_images_A1/19234/2026071984409969.jpg" alt="ç¶ å³¶6å¹´çæç£æ¸¬è§£é22æ°ç´éç¨® èºç£çè å©ä¸è¶³10é»æååæ§æ»çµ">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-mv-text text-black">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Jul. 20 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/article/content-19234.html" class="text-black">
# 										ç¶ å³¶6å¹´çæç£æ¸¬è§£é22æ°ç´éç¨® èºç£çè å©ä¸è¶³10é»æååæ§æ»çµ
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-black mobile-hide">
# 									<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-19234.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 				</div>
# 				<!-- END OF article btn meddle vertical -->
#
#
# 			</div>
#
# 			<!-- END OF top article link -->
#
#
# 			<!-- AD 970250 -->
#
#   <script language="javascript">
#   //alert('2501\na')
#   //AD_FEEL(2501);
#   $(function(){AD_FEEL(2501);});
#   </script>
#   <div class="ad-970250">
#   <p class="ad-tip">AD</p>
#   <!-- img -->
#   <div class="ad-content"><a id="Cartier_AD_Click_Link" href="" target="_blank" rel="noopener noreferrer" class="AD__Banner" data-label="AD_970_250_é »éé 1" onclick="ga('send','event','Banner','click','AD_970_250_é »éé 1');boulder_gtag('event','AD_Banner_View',{'event_category':'AD_Banner','event_label':'AD_970_250_é »éé 1'});">
#       <picture>
#         <source media="(max-width: 1100px)" srcset="https://img.natgeomedia.com/userfiles/images_AD/2026070955401218.jpg" width="300" height="250">
#         <img src="https://img.natgeomedia.com/userfiles/images_AD/2026070955401217.jpg" alt="ad970250" width="970" height="250">
#       </picture>
#     </a>
#   </div>
# </div>
# <script>
#   if ($(window).width() < 1100) {
#     $('#Cartier_AD_Click_Link').attr('href', 'https://ad.doubleclick.net/ddm/trackclk/N2248994.4466732NATGEOMEDIA/B35991412.450821312;dc_trk_aid=644499696;dc_trk_cid=258277853;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;gdpr=${GDPR};gdpr_consent=${GDPR_CONSENT_755};ltd=;dc_tdv=1');
#     $('#Cartier_AD_Click_Link').attr("onclick", "ga('send','event','Banner','click','AD_970_250_é »éé 1-Cartier2026Aug_Mobile');boulder_gtag('event','AD_Banner_View',{'event_category':'AD_Banner','event_label':'AD_970_250_é »éé 1-Cartier2026Aug_Mobile'});");
#     var $ad = $('<div>').css({ 'display': 'none' }).addClass('Cartier_AD_Impressions_Mobile');
#     $ad.append($('<img>').attr('src', 'https://ad.doubleclick.net/ddm/trackimp/N2248994.4466732NATGEOMEDIA/B35991412.450821312;dc_trk_aid=644499696;dc_trk_cid=258277853;ord=[timestamp];dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;gdpr=${GDPR};gdpr_consent=${GDPR_CONSENT_755};ltd=;dc_tdv=1?').css({ 'width': '1px', 'height': '1px' }));
#     var $script = document.createElement("script");
#     $script.type = "text/javascript";
#     $script.src = "https://pixel.adsafeprotected.com/rjss/st/2572167/92574156/skeleton.js";
#     $ad.append($script);
#     var $noscript = document.createElement("noscript");
#     $noscript.append($('<img>').attr('src', 'https://pixel.adsafeprotected.com/rfw/st/2572167/92574155/skeleton.gif?gdpr=${GDPR}&gdpr_consent=${GDPR_CONSENT_278}&gdpr_pd=${GDPR_PD}').css({ 'width': '1px', 'height': '1px' }));
#     $ad.append($noscript);
#   } else {
#     $('#Cartier_AD_Click_Link').attr('href', 'https://ad.doubleclick.net/ddm/trackclk/N2248994.4466732NATGEOMEDIA/B35991412.450821306;dc_trk_aid=644496204;dc_trk_cid=258277853;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;gdpr=${GDPR};gdpr_consent=${GDPR_CONSENT_755};ltd=;dc_tdv=1');
#     $('#Cartier_AD_Click_Link').attr("onclick", "ga('send','event','Banner','click','AD_970_250_é »éé 1-Cartier2026Aug_PC');boulder_gtag('event','AD_Banner_View',{'event_category':'AD_Banner','event_label':'AD_970_250_é »éé 1-Cartier2026Aug_PC'});");
#     var $ad = $('<div>').css({ 'display': 'none' }).addClass('Cartier_AD_Impressions_PC');
#     $ad.append($('<img>').attr('src', 'https://ad.doubleclick.net/ddm/trackimp/N2248994.4466732NATGEOMEDIA/B35991412.450821306;dc_trk_aid=644496204;dc_trk_cid=258277853;ord=[timestamp];dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;gdpr=${GDPR};gdpr_consent=${GDPR_CONSENT_755};ltd=;dc_tdv=1?').css({ 'width': '1px', 'height': '1px' }));
#     var $script = document.createElement("script");
#     $script.type = "text/javascript";
#     $script.src = "https://pixel.adsafeprotected.com/rjss/st/2572167/92573003/skeleton.js";
#     $ad.append($script);
#     var $noscript = document.createElement("noscript");
#     $noscript.append($('<img>').attr('src', 'https://pixel.adsafeprotected.com/rfw/st/2572167/92573002/skeleton.gif?gdpr=${GDPR}&gdpr_consent=${GDPR_CONSENT_278}&gdpr_pd=${GDPR_PD}').css({ 'width': '1px', 'height': '1px' }));
#     $ad.append($noscript);
#   }
#   $('body').append($ad);
# </script>
# 	<script type="text/javascript">boulder_gtag('event','AD_Banner_View',{'event_category':'AD_Banner','event_label':'AD_970_250_é »éé 1-Cartier_2026_8æ'});</script>
# 	<script type="text/javascript">var AD_970_250_Category1=1;</script>
# 			<!-- END OF AD 970250 -->
#
#
# 			<!-- half article link -->
# 			<div class="article-link-w65">
#
# 				<!-- LEFT -->
#
# 				<div class="art-w65-left">
#
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19292.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19292/2026080758638741.jpg" alt="éªå¢">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19292.html" class="text-black">
# 											éªå¢
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										åéç§ä»å·ä¼¼ä¹æ¯ä¸åä¸å¤ªæå¼èµ·æ³¨æãä¹é®®å°æäººææçå°æ¹ãæè¨±æäººæèªçºï¼æ­£å çºææçäººå°ï¼æè©²å¾å®¹ææåºé¢¨æ¯ç§ï¼ä½æå±ä½çç´æ²³è°·ï¼å°å¢ååå¹³å¦ï¼å¾é£æ¾å°è¶³ä»¥å¡«æ»¿ç«é¢çä¸»é«ãåèå¨éå ´å¤§éªä¹å¾ï¼ææ¾å°äºçæ³çæ§å&hellip;ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19292.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19291.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19291/2026080758541665.jpg" alt="æ´é¢¨éª">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19291.html" class="text-black">
# 											æ´é¢¨éª
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										ææ¼ç´ç´å¸é­¯åæãå¨åå½çå¯é¢¨ä¸­ï¼ä¸åå¥³å­æèæ´é¢¨éªéæ¼¸ç± ç½©å±æå¬åã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19291.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19288.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19288/2026080758018373.jpg" alt="å®ç¾é±èº«">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19288.html" class="text-black">
# 											å®ç¾é±èº«
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										ææ¼çå¹²éãåå éçåç©çµéä¹ææï¼æéå°éé»ç¾ç¾ï¼ç éè½éé ­ä¾ï¼ç´è¦èæçé¡é ­ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19288.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- AD Native Category -->
#
#   <script language="javascript">
#   //alert('1224\na')
#   //AD_FEEL(1224);
#   $(function(){AD_FEEL(1224);});
#   </script>
#   <script type="text/javascript">var AD_Native_Category1=0;</script>
# 					<!-- END OF AD Native Category -->
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19286.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19286/2026080757595585.jpg" alt="è·¯éé£²æ°´">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19286.html" class="text-black">
# 											è·¯éé£²æ°´
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										æåä¾å°ç´ç±³æ¯äºçåææ²åå®¶å¬åï¼åºç¼åå°±å·²è½èªªæ­¤ææ¯æä¸é©åæè¡çå­£ç¯ï¼å çºå¤©æ°£çç±åå¤é¨ï¼åç©åæ£ï¼ä¸å®¹æçå°ãååå°èé½æç©æ°´ï¼å æ­¤åç©ä¸æç¹å°èéå°æ°´åå¨åï¼æååªè½éèè»åèå°æ¾ï¼ç¢°ç¢°éæ°£ï¼å¹¸å¥½ç¸½ç®éè¦ä¸ç¾¤çå­å¨è·¯éåæ°´ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19286.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- large -->
# 					<div class="art-btn-la-content">
# 						<a href="https://www.natgeomedia.com/environment/photo/content-19284.html">
# 							<!-- img -->
# 							<div class="art-btn-la-img">
# 								<img src="https://img.natgeomedia.com/userfiles/sm/sm804536_images_A1/19284/2026080757218769.jpg" alt="æ°£æ³¡ççè¦">
# 							</div>
#
# 							<!-- text -->
# 							<div class="art-btn-text art-btn-la-text text-white">
# 								<!-- article-categoty -->
# 								<!-- <h5 class="text-yellow">
# 									<a href="javascript:void(0)" class="text-yellow">
# 										ç§å­¸èæ°ç¥ï½
# 									</a>
# 								</h5> -->
#
# 								<!-- date -->
# 								<h6>Jul. 15 2026</h6>
#
#
#
# 								<!-- article title -->
# 								<h4>
# 									<a href="https://www.natgeomedia.com/environment/photo/content-19284.html" class="text-white">
# 										æ°£æ³¡ççè¦
# 									</a>
# 								</h4>
#
# 								<!-- read btn -->
# 								<div class="read-btn text-white">
# 									<a class="text-white" href="https://www.natgeomedia.com/environment/photo/content-19284.html">
# 										<i class="fas fa-align-justify"></i> Read
# 									</a>
# 								</div>
#
# 							</div>
# 						</a>
# 					</div>
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19283.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19283/2026080756776045.jpg" alt="å¥½å¥çæµ·ç">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19283.html" class="text-black">
# 											å¥½å¥çæµ·ç
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										å¨å å·èå¡è­è­æå³¶å¤æµ·æ½æ°´æï¼ä¸ç¾¤æµ·çåä½äºæï¼éå§åæçç¸æ©åæ°´ä¸éåçç©èãå¶ä¸­éä¸å°æµ·çï¼ç¹å¥èè¿·æ¼èªå·±æ å¨ç¸æ©é²æ°´æ®¼çé¢é¡é ­ç½©ä¸çåå½±ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19283.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19282.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19282/2026080756637113.jpg" alt="æµ·çåæ°´">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19282.html" class="text-black">
# 											æµ·çåæ°´
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										ä¸é ­è¥¿å°åº¦æµ·çå¨ç¾åä½ç¾ééå·ååå­«ç¶­çæ²¿å²¸å§é¸æ°´éæé£²ç¨æ·¡æ°´ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19282.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
# 					<!-- AD Native Category -->
#
#   <script language="javascript">
#   //alert('1225\na')
#   //AD_FEEL(1225);
#   $(function(){AD_FEEL(1225);});
#   </script>
#   <script type="text/javascript">var AD_Native_Category2=0;</script>
# 					<!-- END OF AD Native Category -->
#
# 					<!-- article btn meddle horizontal -->
# 					<div class="artcle-btn-mh artcle-btn-mh-first">
# 						<!-- middle horizontal -->
# 						<div class="art-btn-mh-content">
# 							<a href="https://www.natgeomedia.com/environment/photo/content-19281.html">
# 								<!-- img -->
# 								<div class="art-btn-mh-img">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm322214_images_A1/19281/2026080756486357.jpg" alt="æµ®åºæ°´é¢">
# 								</div>
#
# 								<!-- text -->
# 								<div class="art-btn-text art-btn-mh-text text-black">
# 									<!-- article-categoty -->
# 									<!-- <h5 class="text-yellow">
# 										<a href="javascript:void(0)" class="text-yellow">
# 											ç§å­¸èæ°ç¥ï½
# 										</a>
# 									</h5> -->
#
# 									<!-- date -->
# 									<h6>Jul. 15 2026</h6>
#
#
#
# 									<!-- article title -->
# 									<h4>
# 										<a href="https://www.natgeomedia.com/environment/photo/content-19281.html" class="text-black">
# 											æµ®åºæ°´é¢
# 										</a>
# 									</h4>
#
# 									<!-- article intro -->
# 									<p class="pad-hide">
# 										æµ®ä¸æ°´é¢çæ½é³¥ï¼ææ¼ç¾åå¨æ¯åº·è¾å·éä¼¯æ¯ç¹éè¿çåæ²æ¹ã
#
# æ¬ä½åä¾èªãåå®¶å°çãæå½±ç¤¾ç¾¤ Your Shotã
#
# ä¸è¼ãåå®¶å°çæ¯æ¥ç²¾é¸ Appãï¼æéä¸çç´å½±åæäºã
#
# iOS ð https://lihi.cc/nO9VC
# Android ð https://lihi.cc/7ju77
#
# 									</p>
#
# 									<!-- read btn -->
# 									<div class="read-btn text-black mobile-hide">
# 										<a class="text-black" href="https://www.natgeomedia.com/environment/photo/content-19281.html">
# 											<i class="fas fa-align-justify"></i> Read
# 										</a>
# 									</div>
#
# 								</div>
# 							</a>
# 						</div>
#
# 					</div>
# 					<!-- END OF article btn meddle horizontal -->
#
#
#
# 					<!-- PAGE SWITCH -->
# 					<div class="page-switch">
# 						<ul>
# 							<!-- << --><li class="page-switch-disable"><a href="javascript:void(0)"><i class="fas fa-angle-double-left"></i></a></li>
# <!-- < --><li><a href="javascript:void(0)"><i class="fas fa-angle-left"></i></a></li>
# <!-- number --><li class="page-switch-active"><a href="/environment/index.html?iPage=1">1</a></li>
# <!-- number --><li><a href="/environment/index.html?iPage=2">2</a></li>
# <!-- number --><li><a href="/environment/index.html?iPage=3">3</a></li>
# <!-- number --><li><a href="/environment/index.html?iPage=4">4</a></li>
# <!-- number --><li><a href="/environment/index.html?iPage=5">5</a></li>
# <!-- > --><li><a href="/environment/index.html?iPage=2"><i class="fas fa-angle-right"></i></a></li>
# <!-- >> --><li><a href="/environment/index.html?iPage=350"><i class="fas fa-angle-double-right"></i></a></li>
#
# 						</ul>
# 					</div>
#
# 				</div>
#
#
#
# 				<!-- RIGHT -->
#
#
# 				<div id="right-fixed" class="art-w65-right">
# 					<div class="art-w65-right-wrap">
#
# 						<!-- MAGAZINE AD -->
# 						<div class="magazine-ad">
# 							<div class="mag-ad-content">
# 								<h6>AUG. 2026</h6>
# 								<h4>æ­éç¶­èå¨ç«å±±</h4>
# 								<p>
# 									å°å­å©åå¹´ççæ­»ä¹è¬
# 								</p>
#
# 								<div class="mag-ad-cover">
# 									<img src="https://img.natgeomedia.com/userfiles/sm/sm299437_images_BE2/2026080204992598.jpg" alt="æ­éç¶­èå¨ç«å±±">
# 								</div>
# 							</div>
#
# 							<a href="https://www.natgeomedia.com/e-mag/2026/08/"></a>
# 						</div>
#
# 						<!-- AD 300250 -->
#
#   <script language="javascript">
#   //alert('96\na')
#   //AD_FEEL(96);
#   $(function(){AD_FEEL(96);});
#   </script>
#   <script type="text/javascript">var AD_300_250_Category=0;</script>
# 						<!-- END OF AD 300250 -->
#
#
# 						<!-- article link RIGHT -->
# 						<div class="article-link-right">
# 							<h3>ç±éç²¾é¸</h3>
# 							<div class="art-link-right-content">
#
#
# 								<!-- X-small -->
# 								<div class="art-btn-xs-content">
# 									<a href="https://www.natgeomedia.com/science/article/content-7967.html">
# 										<!-- img -->
# 										<div class="art-btn-xs-img">
# 											<img src="https://img.natgeomedia.com/userfiles/sm/sm10067_images_A1/7967/2019042184094281.jpg" alt="çºä½éé»è²é ­é·¹å°é´¨å¯¶å¯¶è¦å¦å·±åºï¼">
# 										</div>
#
# 										<!-- text -->
# 										<div class="art-btn-text art-btn-xs-text text-black">
# 											<!-- article-categoty -->
# 											<h5 class="text-yellow">
# 												<a href="/science/" class="text-yellow">
# 													ç§å­¸èæ°ç¥ï½
# 												</a>
# 											</h5>
#
# 											<!-- date -->
#
# 											<h6>Apr.21 2019</h6>
#
#
# 											<!-- article title -->
# 											<h4>
# 												<a href="https://www.natgeomedia.com/science/article/content-7967.html" class="text-black">
# 													çºä½éé»è²é ­é·¹å°é´¨å¯¶å¯¶è¦å¦å·±åºï¼
# 												</a>
# 											</h4>
#
# 											<!-- read btn -->
# 											<div class="read-btn text-black desktop-hide mobile-hide">
# 												<a class="text-black" href="https://www.natgeomedia.com/science/article/content-7967.html">
# 													<i class="fas fa-align-justify"></i> Read
# 												</a>
# 											</div>
#
# 										</div>
# 									</a>
# 								</div>
# 								<!-- END OF X-Small -->
#
#
#
# 								<!-- X-small -->
# 								<div class="art-btn-xs-content">
# 									<a href="https://www.natgeomedia.com/science/article/content-19220.html">
# 										<!-- img -->
# 										<div class="art-btn-xs-img">
# 											<img src="https://img.natgeomedia.com/userfiles/sm/sm10067_images_A1/19220/2026071655118577.jpg" alt="å°æ¾å¤©æå­¸å®¶è¿åä¸ç´çãWow!ãè¨èï¼ææ°ç ç©¶æåºæ°è§£é">
# 										</div>
#
# 										<!-- text -->
# 										<div class="art-btn-text art-btn-xs-text text-black">
# 											<!-- article-categoty -->
# 											<h5 class="text-yellow">
# 												<a href="/science/" class="text-yellow">
# 													ç§å­¸èæ°ç¥ï½
# 												</a>
# 											</h5>
#
# 											<!-- date -->
#
# 											<h6>Jul.16 2026</h6>
#
#
# 											<!-- article title -->
# 											<h4>
# 												<a href="https://www.natgeomedia.com/science/article/content-19220.html" class="text-black">
# 													å°æ¾å¤©æå­¸å®¶è¿åä¸ç´çãWow!ãè¨èï¼ææ°ç ç©¶æåºæ°è§£é
# 												</a>
# 											</h4>
#
# 											<!-- read btn -->
# 											<div class="read-btn text-black desktop-hide mobile-hide">
# 												<a class="text-black" href="https://www.natgeomedia.com/science/article/content-19220.html">
# 													<i class="fas fa-align-justify"></i> Read
# 												</a>
# 											</div>
#
# 										</div>
# 									</a>
# 								</div>
# 								<!-- END OF X-Small -->
#
#
#
# 								<!-- X-small -->
# 								<div class="art-btn-xs-content">
# 									<a href="https://www.natgeomedia.com/environment/article/content-18880.html">
# 										<!-- img -->
# 										<div class="art-btn-xs-img">
# 											<img src="https://img.natgeomedia.com/userfiles/sm/sm10067_images_A1/18880/2026022438356781.jpg" alt="èªè­ãå¥³çµãââå¨ä¸çæé·çéçè ï¼">
# 										</div>
#
# 										<!-- text -->
# 										<div class="art-btn-text art-btn-xs-text text-black">
# 											<!-- article-categoty -->
# 											<h5 class="text-yellow">
# 												<a href="/environment/" class="text-yellow">
# 													ç°å¢èä¿è²ï½
# 												</a>
# 											</h5>
#
# 											<!-- date -->
#
# 											<h6>Feb.24 2026</h6>
#
#
# 											<!-- article title -->
# 											<h4>
# 												<a href="https://www.natgeomedia.com/environment/article/content-18880.html" class="text-black">
# 													èªè­ãå¥³çµãââå¨ä¸çæé·çéçè ï¼
# 												</a>
# 											</h4>
#
# 											<!-- read btn -->
# 											<div class="read-btn text-black desktop-hide mobile-hide">
# 												<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-18880.html">
# 													<i class="fas fa-align-justify"></i> Read
# 												</a>
# 											</div>
#
# 										</div>
# 									</a>
# 								</div>
# 								<!-- END OF X-Small -->
#
#
#
# 								<!-- X-small -->
# 								<div class="art-btn-xs-content">
# 									<a href="https://www.natgeomedia.com/environment/article/content-4544.html">
# 										<!-- img -->
# 										<div class="art-btn-xs-img">
# 											<img src="https://img.natgeomedia.com/userfiles/sm/sm10067_images_A1/4544/93631048625.jpg" alt="å¯ãèãç¨å°çæ°ç¨®å¤©å é³¥">
# 										</div>
#
# 										<!-- text -->
# 										<div class="art-btn-text art-btn-xs-text text-black">
# 											<!-- article-categoty -->
# 											<h5 class="text-yellow">
# 												<a href="/environment/" class="text-yellow">
# 													ç°å¢èä¿è²ï½
# 												</a>
# 											</h5>
#
# 											<!-- date -->
#
# 											<h6>May.08 2018</h6>
#
#
# 											<!-- article title -->
# 											<h4>
# 												<a href="https://www.natgeomedia.com/environment/article/content-4544.html" class="text-black">
# 													å¯ãèãç¨å°çæ°ç¨®å¤©å é³¥
# 												</a>
# 											</h4>
#
# 											<!-- read btn -->
# 											<div class="read-btn text-black desktop-hide mobile-hide">
# 												<a class="text-black" href="https://www.natgeomedia.com/environment/article/content-4544.html">
# 													<i class="fas fa-align-justify"></i> Read
# 												</a>
# 											</div>
#
# 										</div>
# 									</a>
# 								</div>
# 								<!-- END OF X-Small -->
#
#
# 							</div>
# 						</div>
# 						<!-- END OF article link RIGHT -->
#
#
# 						<!-- AD 300600 -->
#
#   <script language="javascript">
#   //alert('93\na')
#   //AD_FEEL(93);
#   $(function(){AD_FEEL(93);});
#   </script>
#   <script type="text/javascript">var AD_300_600_Category=0;</script>
# 						<!-- END OF AD 300600 -->
#
#
# 					</div>
#
# 				</div>
#
#
#
# 			</div>
# 			<!-- END OF half article link -->
#
#
# 			<!-- AD 970250 -->
#
#   <script language="javascript">
#   //alert('117\na')
#   //AD_FEEL(117);
#   $(function(){AD_FEEL(117);});
#   </script>
#   <script type="text/javascript">var AD_970_250_Category2=0;</script>
# 			<!-- END OF AD 970250 -->
#
#
# 		</div>
#
#
# 	</section>
#
#
#
#
#
# <!-- <div style="display:none;"><iframe frameborder="0" scrolling="no" id="dadframe" width="1" height="1" style="display:inline;margin: 0;padding: 0; " src="/js/ad.html?t=201711161239"></iframe></div> -->
#
# 	<!-- subscribe -->
# 	<section class="subscribe-area" id="subscribe-edm-area">
# 		<div class="subscribe-area-content">
# 			<!-- title -->
# 			<div class="section-title text-black">
# 				<div class="section-title-eng">Subscribe</div>
# 				<div class="section-title-cht">ç«å³è¨é±</div>
# 			</div>
#
# 			<!-- email input -->
# 			<div class="input-text">
# 				<input type="email" id="EdmEmail" class="text-input" placeholder="è«è¼¸å¥E-mail" onkeypress="if(event.keyCode==13){$('#FormEdmSubmit').trigger('click');}">
# 				<button type="button" id="FormEdmSubmit" class="input-submit-btn" aria-label="Subscribe ç«å³è¨é±">
# 					<i class="fas fa-arrow-right"></i>
# 				</button>
# 			</div>
#
# 		</div>
# 	</section>
#
# 	<script type="text/javascript">
# 	$(function(){
# 		$('#FormEdmSubmit').click(function(){
#
# 			if($('#EdmEmail').val()==''){
# 				alert('è«è¼¸å¥E-Mail!!');
# 				$('#EdmEmail').focus();
# 			}else{
# 				var regExpEmail=/^[_a-z0-9-]+([.][_a-z0-9-]+)*@[a-z0-9-]+([.][a-z0-9-]+)*.[a-z0-9-]+([.][a-z0-9-]+)/;
# 				if($('#EdmEmail').val().match(regExpEmail)){
# 					ga('send','event','Button','click','Subscribe EDM');
# 					$.ajax({
# 						url:'/member/subscribe-edm.asp',
# 						type:'GET',
# 						data:{email:$('#EdmEmail').val()},
# 						dataType:'json',
# 						success: function(Jdata) {
# 							alert(Jdata.msg);
# 							if(parseInt(Jdata.err)==0){
# 								$('#EdmEmail').val('');
# 							}
# 						},
# 						error: function() {
# 							alert("subscribe-edm ERROR!!!");
# 						}
# 					});
# 				}else{
# 					alert('E-Mailè¼¸å¥æèª¤!!!');
# 					$('#EdmEmail').focus();
# 				}
# 			}
# 		});
# 	});
# 	</script>
#
#
#
# 	<!-- footer -->
# 	<footer>
# 		<div class="footer-container">
#
# 			<div class="footer-logo">
# 				<a href="/" aria-label="åå®¶å°ç"><img src="https://img.natgeomedia.com/img/ngm-logo-w.svg" alt="åå®¶å°ç"></a>
# 			</div>
#
# 			<div class="footer-social">
# 				<p>Follow Us</p>
# 				<ul>
# 					<li>
# 						<a href="https://www.facebook.com/natgeomedia" aria-label="åå®¶å°ç Facebook" target="_blank" rel="noopener noreferrer">
# 							<i class="fab fa-facebook-square"></i>
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://www.instagram.com/natgeo.media/" aria-label="åå®¶å°ç Instagram" target="_blank" rel="noopener noreferrer">
# 							<i class="fab fa-instagram"></i>
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://www.youtube.com/channel/UCtmb2nQhbT2rxxpmbdRjvVg" aria-label="åå®¶å°ç Youtube" target="_blank" rel="noopener noreferrer">
# 							<i class="fab fa-youtube"></i>
# 						</a>
# 					</li>
#
# 					<!-- <li>
# 						<a href="https://line.me/R/ti/p/%40bme3649c" aria-label="åå®¶å°ç LINE" target="_blank" rel="noopener noreferrer">
# 							<i class="fab fa-line"></i>
# 						</a>
# 					</li> -->
#
# 					<li>
# 						<a href="https://twitter.com/tc_natgeo" aria-label="åå®¶å°ç Twitter" target="_blank" rel="noopener noreferrer">
# 							<img src="https://img.natgeomedia.com/img/twitter-x.svg" alt="twitter">
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://www.threads.net/@natgeo.media" aria-label="åå®¶å°ç Threads" target="_blank" rel="noopener noreferrer">
# 							<img src="https://img.natgeomedia.com/img/threads-logo.svg" alt="threads">
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://t.me/natgeomedia" aria-label="åå®¶å°ç" target="_blank" rel="noopener noreferrer">
# 							<i class="fab fa-telegram-plane"></i>
# 						</a>
# 					</li>
# 				</ul>
# 			</div>
#
# 			<div class="clearfix"></div>
#
# 			<div class="footer-link">
# 				<ul>
# 					<li>
# 						<a href="/aboutus.html" aria-label="éæ¼æå">
# 							éæ¼æå
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://www.nationalgeographic.com/" aria-label="ç¾ååå®¶å°ç" target="_blank" rel="noopener noreferrer">
# 							ç¾ååå®¶å°ç
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="/term.html" aria-label="ç¸éè²ææ¢æ¬¾">
# 							ç¸éè²ææ¢æ¬¾
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="/qa.html" aria-label="å¸¸è¦åé¡">
# 							å¸¸è¦åé¡
# 						</a>
# 					</li>
#
# 					<li>
# 						<!-- <a href="/file/mediakit.pdf" target="_blank"> -->
# 						<a href="mailto:ko.kelly@natgeomedia.com" aria-label="å»£ååç»" target="_blank">
# 							å»£ååç»
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="/magazine.html" aria-label="éèªè¨é±">
# 							éèªè¨é±
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="/member/paywall.asp" aria-label="æ¸ä½å¨é±è®">
# 							æ¸ä½å¨é±è®
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://lihi.cc/qL7OO" aria-label="å¤§ç³åå" target="_blank">
# 							å¤§ç³åå
# 						</a>
# 					</li>
#
# 					<li>
# 						<a href="https://www.natgeomedia.com/scienceclub/" aria-label="å°å¹´ç§å­¸ä¿±æ¨é¨" target="_blank">
# 							å°å¹´ç§å­¸ä¿±æ¨é¨
# 						</a>
# 					</li>
#
# 				</ul>
# 			</div>
#
# 			<div class="footer-copyright">
# 				<p>
# 					æåæéï¼é±ä¸è³é±äº 09:00-18:00  <br class="footer-mobile">å®¢æä¿¡ç®±ï¼cservice@natgeomedia.com ï½ å®¢æé»è©±ï¼02-2697-1600
# 				</p>
# 				<p>Â© 2026 Boulder Media Inc, Taiwan / National Geographic</p>
# 			</div>
# 		</div>
# 	</footer>
#
#
# 	<script defer type="text/javascript" src="https://img.natgeomedia.com/scripts/adajax.js"></script>
#
# 	<script defer type="text/javascript" src="https://img.natgeomedia.com/scripts/address.js"></script>
# 	<script defer type="text/javascript" src="https://img.natgeomedia.com/scripts/form_check.js"></script>
#
#
#
# 	<!-- Google AdSense JS -->
# 	<script defer src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
# 	<!-- 3rd Party Ads Display Network -->
# 	<script defer src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
#
#
# 	<!-- Lazyload -->
# 	<script src="https://img.natgeomedia.com/js/lazyload.min.js"></script>
# 	<script>$(function(){var myLazyLoad = new LazyLoad();});</script>
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <!-- <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PZNPVHG"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript> -->
# <!-- End Google Tag Manager (noscript) -->
#
#
# <!-- Google Analytics -->
# <!-- <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-48305649-1', 'auto');
# 	ga('send', 'pageview');
#
# 	setTimeout("ga('send', 'event', '1_seconds', 'read')",1000);
# </script> -->
#
#
# <!-- 20190403 comScore Tag Add to GTM -->
# <!-- Begin comScore Tag -->
# 	<!--
# 	<script>
# 		var _comscore = _comscore || [];
# 		_comscore.push({ c1: "2", c2: "27163232" });
# 		(function() {
# 			var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 			s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 			el.parentNode.insertBefore(s, el);
# 		})();
# 	</script>
# 	<noscript>
# 		<img src="https://sb.scorecardresearch.com/p?c1=2&c2=27163232&cv=2.0&cj=1" />
# 	</noscript>
# 	-->
# <!-- End comScore Tag -->
#
#
# <!-- 20190403 Facebook Pixel Add to GTM -->
# <!-- Facebook Pixel Code -->
# 	<script>
# 	window.addEventListener("load", function(){
# 		setTimeout(function(){
# 			!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');
# 			fbq('init', '279214589239037');
# 			fbq('track', 'PageView');
# 		}, 5000); // 5 ç§å¾åè¼å¥
# 	});
# 	</script>
#
# 	<noscript>
# 		<img height="1" width="1" src="https://www.facebook.com/tr?id=279214589239037&ev=PageView&noscript=1"/>
# 	</noscript>
# <!-- End Facebook Pixel Code -->
#
#
#
#
# 	<!--top-->
# 	<div id="gotop">
# 		<i class="material-icons">keyboard_arrow_up</i>
# 	</div>
#
#
#   <script language="javascript">
#   //alert('87\na')
#   //AD_FEEL(87);
#   $(function(){AD_FEEL(87);});
#   </script>
#   <script type="text/javascript">var AD_Cover=0;</script>
#   <script language="javascript">
#   //alert('856\na')
#   //AD_FEEL(856);
#   $(function(){AD_FEEL(856);});
#   </script>
#   <script type="text/javascript">var AD_FixedCover=0;</script>
#
# 	<script src="/js/main.js?v=20251210"></script>
#
#
#
# </body>
# </html>
#
# [<div class="art-btn-la-img">
# <img alt="æ¸æçª©å¨æ²è£¡ä¹è½çå­ åèå¯æçãæ²æ¼ é¨èãé£æµäººé¡éç¼" src="https://img.natgeomedia.com/userfiles/sm/sm564376_images_A1/19297/2026081044645521.jpg"/>
# </div>, <div class="art-btn-la-img">
# <img alt="æ°£æ³¡ççè¦" src="https://img.natgeomedia.com/userfiles/sm/sm804536_images_A1/19284/2026080757218769.jpg"/>
# </div>]

# %%
import os

os.makedirs("./img/", exist_ok=True)

# %%
for div in img_div:
    imgs = div.find_all("img")
    for img in imgs:
        url = img["src"]
        r = requests.get(url, stream=True)
        image_name = url.split("/")[-1]
        with open("./img/%s" % image_name, "wb") as f:
            for chunk in r.iter_content(chunk_size=128):
                f.write(chunk)
            print("Saved %s" % image_name)
# Out:
# Saved 2026081044645521.jpg
# Saved 2026080757218769.jpg

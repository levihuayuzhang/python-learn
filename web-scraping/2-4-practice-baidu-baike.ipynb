# %%
import random
import re
from urllib.parse import quote
from urllib.request import Request, urlopen

from bs4 import BeautifulSoup

base_url = "https://baike.baidu.com"
his = ["/item/网络爬虫/5162711"]
# his = ["/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711"]

# %%
url = base_url + quote(his[-1], safe="/")

print("his[-1] =", his[-1])
print("url      =", url)

req = Request(
    url,
    headers={
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/139.0.0.0 Safari/537.36"
        ),
        "Accept": (
            "text/html,application/xhtml+xml,"
            "application/xml;q=0.9,image/avif,image/webp,"
            "*/*;q=0.8"
        ),
        "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8",
        "Accept-Encoding": "gzip, deflate",
        "Connection": "keep-alive",
    },
)

from urllib.error import HTTPError

try:
    response = urlopen(req)
except HTTPError as e:
    print(e.code)
    print(e.headers)
    print(e.read().decode("utf-8", errors="replace")[:3000])

html = urlopen(req).read().decode("utf-8")
soup = BeautifulSoup(html, features="lxml")
print(soup.find("h1").get_text(), "     url: ", his[-1])
# Out:
# his[-1] = /item/网络爬虫/5162711
# url      = https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 403
# Content-Encoding: gzip
# Content-Length: 1317
# Content-Security-Policy-Report-Only: default-src https: 'unsafe-inline' 'unsafe-eval' data: blob: ; report-uri https://reports.baidu.com/csp-report/baike
# Content-Type: text/html; charset=utf-8
# Server: bfe
# Set-Cookie: BAIDUID=FDC041F90EF29D662595ACF00D90C33C:FG=1; Path=/; Domain=baidu.com; Max-Age=31536000
# Set-Cookie: BAIDUID_BFESS=FDC041F90EF29D662595ACF00D90C33C:FG=1; Path=/; Domain=baidu.com; Max-Age=31536000; Secure; SameSite=None
# Date: Tue, 18 Aug 2026 12:58:43 GMT
# Connection: close
#
#
# ��V[o�F�+��
# I�B+�$�K��"�oٍ�X8��869df�������c��@[�Eч�Z(����S�B1CQ��ȋf��~�2g�X���v;9O~��~s>f}��o6<�n���9�a.@������j~,�����4��\~�^n�A�%u|ȓ�I`��>d6��
# ;�4�������0��OYm�aץ�_[Lv�o�i����(��;> �
# �ٰ�e�\�C�N#Y.7B�IC���e暩�Dk�n+!��K!��a��Y�֐�L�QQј�Y@� a� ��sg�V1װ�d�Y�!s>�b߯�Tk)ec%Ʉ���9�o��894f�G�?�����'8�u��|���nN�9���-5�$O�9MKd
# NJa$��j�y.E#7$qL,��:�F�6��*�ea/��BF�ް��AJZתa��U��FäND��h&k�D(��w��!�Bڧx��΀ٝ���a42b�[�`��dz1(�D�/,h-�IC�� ��
# �+��n���{���9@C|V3�Ӈkw7��x+�x�u��?����w�c��U0J"v�[3L��$"'>�p�\Țq��5�U77WN��k]/-�n�m����`GVC��k���x�7κ���창t�zx����Q���������x�?-�׊�wx/�K=��u.�`�^�h��tln��w������}h�L�b��5�EͶ5׊��WH�TB`:+��Fa��7��Z[mVW��Bg���VXo�K��+ժQ"~(@M�Z���k)5g:[���>e�gJ����F%ⲊC�	�bd����\���`��H�D7������ک���r��,�[W(*��`v���a�*�5WN��"�P
# p:#,��P��4!��D�Z>%`ZڝW^�ۦX_�E5�ff�~-rX���<5,+_�L�+�G{Ҵ�355��<�\�Y��c�֦�$V��g�4�<O�RI��<�v��D���
# �V�f�8��a���;��U*$���q��O7�~q��g�/_^}����_��˳��/��{���ߧڛw?�~��a�I�D�CE?q�MR��5_K�^ghI}���
# �m�Uʭ�2������?���N���
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[29], line 34
#      30     print(e.code)
#      31     print(e.headers)
#      32     print(e.read().decode("utf-8", errors="replace")[:3000])
#      33
# ---> 34 html = urlopen(req).read().decode("utf-8")
#      35 soup = BeautifulSoup(html, features="lxml")
#      36 print(soup.find("h1").get_text(), "     url: ", his[-1])
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:187, in urlopen(url, data, timeout, context)
#     185 else:
#     186     opener = _opener
# --> 187 return opener.open(url, data, timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:493, in OpenerDirector.open(self, fullurl, data, timeout)
#     491 for processor in self.process_response.get(protocol, []):
#     492     meth = getattr(processor, meth_name)
# --> 493     response = meth(req, response)
#     495 return response
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:602, in HTTPErrorProcessor.http_response(self, request, response)
#     599 # According to RFC 2616, "2xx" code indicates that the client's
#     600 # request was successfully received, understood, and accepted.
#     601 if not (200 <= code < 300):
# --> 602     response = self.parent.error(
#     603         'http', request, response, code, msg, hdrs)
#     605 return response
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:531, in OpenerDirector.error(self, proto, *args)
#     529 if http_err:
#     530     args = (dict, 'default', 'http_error_default') + orig_args
# --> 531     return self._call_chain(*args)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:464, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     462 for handler in handlers:
#     463     func = getattr(handler, meth_name)
# --> 464     result = func(*args)
#     465     if result is not None:
#     466         return result
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\urllib\request.py:611, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     610 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 611     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
